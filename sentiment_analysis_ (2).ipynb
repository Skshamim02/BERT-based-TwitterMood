# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# Get the file from the user's Google Drive
file_path = '/labeled_tweets_dataset.csv'

# Read the file into a pandas DataFrame
df = pd.read_csv(file_path, encoding='latin1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(df)
# Out:
#        Unnamed: 0              user  \
# 0               0    @ahmadwaraichh
# 1               1  @W97537438Denise
# 2               2     @nair_nandu08
# 3               3          @Byron47
# 4               4   @Period65995738
# ...           ...               ...
# 11221       11221      @binaratmaja
# 11222       11222  @Chic_AvantGarde
# 11223       11223     @GeorgeProust
# 11224       11224       @GemYardBTC
# 11225       11225  @DivisiveContent
#
#                                                    tweet  \
# 0      Former minister in Shahbaz Sharif's cabinet, w...
# 1      No we have a catastrophe in our House! It wasn...
# 2      This man @AbhishekJa98788  is using my dp and ...
# 3      Inside Elon Musk's Neuralink lab where 1,500 a...
# 4      An apology isn't accountability.   He broke th...
# ...                                                  ...
# 11221  elonmusk: @Culture_Crit What a crazy thing for...
# 11222  I'll start a thread posting the spam accounts,...
# 11223  This is a lot easier to do IF you don't rely o...
# 11224                             @elonmusk GROQ on GROK
# 11225  The US has gone full corruption. Political ide...
#
#                                       preprocessed_tweet sentiment
# 0      former minister shahbaz sharif cabinet pledged...   neutral
# 1      catastrophe house border life america american...  negative
# 2      man abhishekja98788 using dp name elonmusk twi...   neutral
# 3      inside elon musk neuralink lab animal killed t...  negative
# 4                       apology accountability broke law   neutral
# ...                                                  ...       ...
# 11221                           elonmusk crazy thing say  negative
# 11222  start thread posting spam account blocked cait...   neutral
# 11223               lot easier rely traitorous elon musk   neutral
# 11224                                 elonmusk groq grok   neutral
# 11225  u gone full corruption political ideology dete...  positive
#
# [11226 rows x 5 columns]

# %%
# Replace the sentiment strings with numerical codes
sentiment_mapping = {'neutral': 0, 'positive': 2, 'negative': 1}
df['sentiment'] = df['sentiment'].map(sentiment_mapping)

# %%
print(df)
# Out:
#        Unnamed: 0              user  \
# 0               0    @ahmadwaraichh
# 1               1  @W97537438Denise
# 2               2     @nair_nandu08
# 3               3          @Byron47
# 4               4   @Period65995738
# ...           ...               ...
# 11221       11221      @binaratmaja
# 11222       11222  @Chic_AvantGarde
# 11223       11223     @GeorgeProust
# 11224       11224       @GemYardBTC
# 11225       11225  @DivisiveContent
#
#                                                    tweet  \
# 0      Former minister in Shahbaz Sharif's cabinet, w...
# 1      No we have a catastrophe in our House! It wasn...
# 2      This man @AbhishekJa98788  is using my dp and ...
# 3      Inside Elon Musk's Neuralink lab where 1,500 a...
# 4      An apology isn't accountability.   He broke th...
# ...                                                  ...
# 11221  elonmusk: @Culture_Crit What a crazy thing for...
# 11222  I'll start a thread posting the spam accounts,...
# 11223  This is a lot easier to do IF you don't rely o...
# 11224                             @elonmusk GROQ on GROK
# 11225  The US has gone full corruption. Political ide...
#
#                                       preprocessed_tweet  sentiment
# 0      former minister shahbaz sharif cabinet pledged...          0
# 1      catastrophe house border life america american...          1
# 2      man abhishekja98788 using dp name elonmusk twi...          0
# 3      inside elon musk neuralink lab animal killed t...          1
# 4                       apology accountability broke law          0
# ...                                                  ...        ...
# 11221                           elonmusk crazy thing say          1
# 11222  start thread posting spam account blocked cait...          0
# 11223               lot easier rely traitorous elon musk          0
# 11224                                 elonmusk groq grok          0
# 11225  u gone full corruption political ideology dete...          2
#
# [11226 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11226 entries, 0 to 11225
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          11226 non-null  int64
#  1   user                11226 non-null  object
#  2   tweet               10855 non-null  object
#  3   preprocessed_tweet  10318 non-null  object
#  4   sentiment           11226 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 438.6+ KB

# %%
df = df[['preprocessed_tweet','sentiment']]

# %%
df
# Out:
#                                       preprocessed_tweet  sentiment
# 0      former minister shahbaz sharif cabinet pledged...          0
# 1      catastrophe house border life america american...          1
# 2      man abhishekja98788 using dp name elonmusk twi...          0
# 3      inside elon musk neuralink lab animal killed t...          1
# 4                       apology accountability broke law          0
# ...                                                  ...        ...
# 11221                           elonmusk crazy thing say          1
# 11222  start thread posting spam account blocked cait...          0
# 11223               lot easier rely traitorous elon musk          0
# 11224                                 elonmusk groq grok          0
# 11225  u gone full corruption political ideology dete...          2
#
# [11226 rows x 2 columns]

# %%
text_len = []
for text in df.preprocessed_tweet:
    if isinstance(text, str):  # Check if the value is a string
        tweet_len = len(text.split())
        text_len.append(tweet_len)
    else:
        text_len.append(0)  # Or handle the NaN/float case as needed, e.g., append 0 or None

# %%
df['text_len'] = text_len

# %%
text_len
# Out:
# [25,
#  14,
#  11,
#  12,
#  4,
#  0,
#  48,
#  15,
#  3,
#  15,
#  3,
#  3,
#  1,
#  1,
#  36,
#  5,
#  184,
#  17,
#  28,
#  13,
#  1,
#  9,
#  8,
#  6,
#  5,
#  77,
#  6,
#  0,
#  26,
#  8,
#  5,
#  37,
#  26,
#  0,
#  20,
#  9,
#  23,
#  22,
#  4,
#  19,
#  9,
#  14,
#  20,
#  1,
#  2,
#  1,
#  24,
#  53,
#  11,
#  0,
#  27,
#  19,
#  27,
#  23,
#  23,
#  16,
#  9,
#  10,
#  0,
#  2,
#  2,
#  11,
#  0,
#  6,
#  4,
#  15,
#  25,
#  17,
#  13,
#  0,
#  16,
#  9,
#  8,
#  27,
#  2,
#  17,
#  3,
#  3,
#  8,
#  9,
#  27,
#  9,
#  0,
#  5,
#  19,
#  9,
#  0,
#  2,
#  25,
#  3,
#  3,
#  12,
#  20,
#  20,
#  7,
#  5,
#  3,
#  5,
#  0,
#  33,
#  43,
#  16,
#  18,
#  30,
#  25,
#  19,
#  5,
#  6,
#  25,
#  1,
#  3,
#  27,
#  21,
#  19,
#  1,
#  0,
#  4,
#  2,
#  16,
#  15,
#  2,
#  6,
#  2,
#  40,
#  0,
#  44,
#  2,
#  9,
#  27,
#  2,
#  1,
#  5,
#  4,
#  19,
#  6,
#  34,
#  3,
#  4,
#  15,
#  9,
#  7,
#  19,
#  10,
#  10,
#  13,
#  19,
#  9,
#  2,
#  6,
#  5,
#  1,
#  4,
#  5,
#  12,
#  5,
#  14,
#  6,
#  12,
#  4,
#  14,
#  38,
#  18,
#  18,
#  13,
#  0,
#  111,
#  2,
#  32,
#  8,
#  12,
#  22,
#  7,
#  16,
#  17,
#  4,
#  2,
#  3,
#  8,
#  4,
#  4,
#  4,
#  8,
#  14,
#  9,
#  20,
#  18,
#  7,
#  22,
#  3,
#  4,
#  1,
#  21,
#  19,
#  23,
#  2,
#  1,
#  18,
#  4,
#  0,
#  3,
#  22,
#  20,
#  2,
#  7,
#  3,
#  0,
#  2,
#  6,
#  8,
#  2,
#  2,
#  8,
#  7,
#  2,
#  24,
#  17,
#  3,
#  31,
#  9,
#  18,
#  20,
#  1,
#  2,
#  22,
#  31,
#  4,
#  18,
#  7,
#  1,
#  2,
#  25,
#  6,
#  10,
#  2,
#  28,
#  2,
#  1,
#  0,
#  0,
#  6,
#  1,
#  7,
#  1,
#  14,
#  9,
#  16,
#  0,
#  21,
#  2,
#  5,
#  4,
#  1,
#  6,
#  1,
#  8,
#  10,
#  1,
#  28,
#  20,
#  4,
#  1,
#  4,
#  20,
#  1,
#  1,
#  0,
#  0,
#  2,
#  5,
#  38,
#  17,
#  0,
#  3,
#  8,
#  23,
#  22,
#  17,
#  12,
#  11,
#  10,
#  9,
#  15,
#  24,
#  8,
#  1,
#  0,
#  6,
#  20,
#  4,
#  26,
#  2,
#  0,
#  9,
#  0,
#  7,
#  3,
#  5,
#  16,
#  0,
#  4,
#  28,
#  2,
#  10,
#  28,
#  2,
#  11,
#  2,
#  3,
#  0,
#  4,
#  0,
#  6,
#  15,
#  38,
#  6,
#  12,
#  18,
#  6,
#  10,
#  4,
#  4,
#  21,
#  11,
#  2,
#  4,
#  2,
#  2,
#  12,
#  19,
#  7,
#  14,
#  3,
#  0,
#  11,
#  0,
#  3,
#  24,
#  11,
#  12,
#  14,
#  0,
#  23,
#  4,
#  14,
#  2,
#  7,
#  4,
#  6,
#  8,
#  9,
#  20,
#  3,
#  1,
#  10,
#  16,
#  15,
#  5,
#  6,
#  13,
#  1,
#  24,
#  10,
#  4,
#  7,
#  7,
#  1,
#  2,
#  6,
#  8,
#  8,
#  44,
#  27,
#  3,
#  0,
#  6,
#  11,
#  15,
#  20,
#  17,
#  5,
#  21,
#  0,
#  12,
#  16,
#  14,
#  24,
#  4,
#  6,
#  7,
#  10,
#  17,
#  12,
#  23,
#  2,
#  12,
#  14,
#  16,
#  28,
#  7,
#  1,
#  10,
#  7,
#  10,
#  7,
#  4,
#  12,
#  10,
#  0,
#  13,
#  1,
#  9,
#  34,
#  8,
#  6,
#  0,
#  1,
#  3,
#  13,
#  9,
#  67,
#  550,
#  17,
#  21,
#  1,
#  0,
#  1,
#  0,
#  8,
#  7,
#  12,
#  1,
#  12,
#  27,
#  3,
#  26,
#  9,
#  10,
#  8,
#  2,
#  1,
#  15,
#  0,
#  14,
#  20,
#  18,
#  14,
#  15,
#  9,
#  9,
#  11,
#  56,
#  4,
#  3,
#  16,
#  52,
#  4,
#  25,
#  1,
#  3,
#  18,
#  5,
#  21,
#  3,
#  1,
#  3,
#  7,
#  11,
#  9,
#  10,
#  9,
#  23,
#  2,
#  13,
#  32,
#  17,
#  0,
#  20,
#  1,
#  10,
#  20,
#  3,
#  43,
#  16,
#  0,
#  21,
#  17,
#  1,
#  7,
#  2,
#  12,
#  4,
#  17,
#  2,
#  14,
#  1,
#  5,
#  10,
#  3,
#  3,
#  6,
#  16,
#  1,
#  11,
#  13,
#  1,
#  7,
#  19,
#  12,
#  5,
#  23,
#  21,
#  1,
#  4,
#  21,
#  16,
#  12,
#  11,
#  7,
#  5,
#  23,
#  4,
#  8,
#  2,
#  2,
#  5,
#  3,
#  20,
#  2,
#  28,
#  23,
#  10,
#  9,
#  2,
#  15,
#  5,
#  25,
#  30,
#  13,
#  10,
#  3,
#  2,
#  2,
#  0,
#  2,
#  2,
#  3,
#  7,
#  22,
#  0,
#  8,
#  18,
#  21,
#  2,
#  25,
#  1,
#  12,
#  2,
#  7,
#  0,
#  1,
#  27,
#  21,
#  3,
#  9,
#  12,
#  3,
#  0,
#  3,
#  69,
#  17,
#  4,
#  4,
#  1,
#  9,
#  4,
#  23,
#  11,
#  9,
#  0,
#  15,
#  7,
#  23,
#  3,
#  25,
#  1,
#  6,
#  1,
#  1,
#  1,
#  16,
#  3,
#  3,
#  10,
#  40,
#  0,
#  32,
#  3,
#  1,
#  10,
#  11,
#  19,
#  0,
#  6,
#  4,
#  8,
#  4,
#  10,
#  22,
#  8,
#  5,
#  34,
#  24,
#  18,
#  0,
#  9,
#  6,
#  3,
#  4,
#  0,
#  8,
#  8,
#  5,
#  18,
#  4,
#  4,
#  0,
#  0,
#  23,
#  2,
#  14,
#  2,
#  28,
#  4,
#  8,
#  5,
#  4,
#  5,
#  20,
#  8,
#  8,
#  4,
#  5,
#  25,
#  1,
#  36,
#  11,
#  13,
#  9,
#  10,
#  7,
#  21,
#  1,
#  3,
#  14,
#  1,
#  4,
#  7,
#  0,
#  33,
#  11,
#  14,
#  6,
#  10,
#  0,
#  4,
#  15,
#  7,
#  9,
#  10,
#  5,
#  8,
#  36,
#  5,
#  1,
#  25,
#  1,
#  4,
#  9,
#  1,
#  10,
#  3,
#  12,
#  3,
#  7,
#  14,
#  1,
#  20,
#  6,
#  87,
#  20,
#  8,
#  3,
#  4,
#  8,
#  0,
#  8,
#  24,
#  8,
#  2,
#  8,
#  0,
#  35,
#  1,
#  9,
#  8,
#  2,
#  15,
#  3,
#  24,
#  8,
#  23,
#  19,
#  1,
#  21,
#  6,
#  10,
#  3,
#  6,
#  6,
#  0,
#  1,
#  14,
#  35,
#  14,
#  12,
#  25,
#  4,
#  19,
#  14,
#  1,
#  8,
#  4,
#  5,
#  21,
#  22,
#  107,
#  9,
#  37,
#  14,
#  0,
#  28,
#  10,
#  4,
#  3,
#  0,
#  2,
#  73,
#  8,
#  1,
#  27,
#  7,
#  8,
#  11,
#  18,
#  6,
#  2,
#  3,
#  3,
#  6,
#  4,
#  12,
#  8,
#  2,
#  9,
#  0,
#  1,
#  6,
#  19,
#  1,
#  10,
#  24,
#  3,
#  8,
#  11,
#  12,
#  0,
#  21,
#  12,
#  6,
#  4,
#  9,
#  7,
#  11,
#  1,
#  7,
#  7,
#  4,
#  4,
#  0,
#  12,
#  3,
#  22,
#  21,
#  12,
#  12,
#  5,
#  1,
#  10,
#  15,
#  9,
#  24,
#  4,
#  7,
#  9,
#  22,
#  17,
#  3,
#  1,
#  18,
#  3,
#  1,
#  7,
#  30,
#  21,
#  16,
#  15,
#  14,
#  10,
#  5,
#  6,
#  20,
#  1,
#  11,
#  9,
#  3,
#  3,
#  4,
#  17,
#  0,
#  1,
#  22,
#  0,
#  35,
#  2,
#  1,
#  34,
#  3,
#  9,
#  12,
#  4,
#  24,
#  10,
#  2,
#  7,
#  7,
#  1,
#  7,
#  9,
#  0,
#  10,
#  20,
#  1,
#  11,
#  2,
#  3,
#  1,
#  1,
#  2,
#  6,
#  3,
#  23,
#  9,
#  11,
#  11,
#  11,
#  22,
#  6,
#  3,
#  5,
#  26,
#  15,
#  2,
#  18,
#  11,
#  0,
#  11,
#  2,
#  21,
#  5,
#  12,
#  3,
#  2,
#  4,
#  0,
#  2,
#  9,
#  8,
#  2,
#  4,
#  55,
#  2,
#  5,
#  7,
#  11,
#  18,
#  3,
#  10,
#  19,
#  24,
#  13,
#  14,
#  4,
#  49,
#  6,
#  5,
#  3,
#  3,
#  1,
#  19,
#  1,
#  5,
#  40,
#  14,
#  0,
#  24,
#  3,
#  6,
#  21,
#  2,
#  4,
#  6,
#  4,
#  22,
#  23,
#  95,
#  1,
#  1,
#  1,
#  5,
#  8,
#  15,
#  10,
#  17,
#  0,
#  7,
#  43,
#  0,
#  1,
#  3,
#  23,
#  8,
#  9,
#  14,
#  13,
#  11,
#  10,
#  8,
#  1,
#  6,
#  5,
#  21,
#  2,
#  1,
#  0,
#  1,
#  0,
#  13,
#  9,
#  3,
#  6,
#  14,
#  0,
#  21,
#  22,
#  1,
#  8,
#  1,
#  2,
#  7,
#  1,
#  20,
#  1,
#  5,
#  3,
#  4,
#  12,
#  23,
#  3,
#  1,
#  3,
#  31,
#  14,
#  3,
#  25,
#  46,
#  8,
#  19,
#  10,
#  11,
#  14,
#  26,
#  2,
#  0,
#  9,
#  4,
#  14,
#  0,
#  8,
#  3,
#  22,
#  ...]

# %%
text_len_test = []
for text in df.preprocessed_tweet:
    if isinstance(text, str):  # Check if the value is indeed a string
        tweet_len = len(text.split())
    else:
        tweet_len = 0  # Assign 0 or any appropriate value for non-string values
    text_len_test.append(tweet_len)

# %%
df['text_len'] = text_len_test

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Your plotting code here
plt.figure(figsize=(7,5))
ax = sns.countplot(x='text_len', data=df[df['text_len']<40], palette='mako')
plt.title(' tweets with less than 40 words')
plt.yticks([])
ax.bar_label(ax.containers[0])
plt.ylabel('count')
plt.xlabel('')
plt.show()
# Out:
# <ipython-input-76-137fc67924ba>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='text_len', data=df[df['text_len']<40], palette='mako')

# %%
#As we can see, there are lots of cleaned tweets with 0 words: this is due to the cleaning performed before.
# This means that some tweets contained only mentions, hashtags and links, which have been removed. We will drop these empty tweets and also those with less than 5 words.

# %%
print(f" DF SHAPE: {df.shape}")
# Out:
#  DF SHAPE: (11226, 3)

# %%
df = df[df['text_len'] > 3]

# %%
print(f" DF SHAPE: {df.shape}")
# Out:
#  DF SHAPE: (7213, 3)

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
from transformers import BertTokenizerFast

tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')

# %%
import numpy as np

# %%
token_lens = []

for txt in df['preprocessed_tweet'].values:
    tokens = tokenizer.encode(txt, max_length=512, truncation=True)
    token_lens.append(len(tokens))

max_len=np.max(token_lens)

# %%
print(f"MAX TOKENIZED SENTENCE LENGTH: {max_len}")
# Out:
# MAX TOKENIZED SENTENCE LENGTH: 512

# %%
token_lens = []

for i,txt in enumerate(df['preprocessed_tweet'].values):
    tokens = tokenizer.encode(txt, max_length=512, truncation=True)
    token_lens.append(len(tokens))
    if len(tokens)>80:
        print(f"INDEX: {i}, TEXT: {txt}")
# Out:
# INDEX: 10, TEXT: judge kathaleen mccormick rescinded elon musk 55 billion tesla compensation package overturning company board 80 shareholder mccormick also ruled elonmusk twitter acquisition becoming head delaware chancery court mccormick worked delaware law firm called young conaway firm employee major donor president joe biden decade 2016 hunter biden hosted gubernatorial campaign event congressman john carney president joe biden guest speaker event took place law office young conaway wilmington delaware carney close friend joe biden last four decade later became governor nominated kathaleen mccormick partner young conaway position delaware chancery court march 2018 email hunter biden claimed personally know every judge delaware chancery court threatening legal action chinese business partner bring suit chancery court delaware know home state privileged worked know every judge chancery court elon musk purchased twitter stated goal restoring president biden called federal investigation musk podium white house following biden department justice security exchange commission federal trade commission initiated legal action investigation tesla spacex x recent decision judge mccormick worked biden top donor nominated biden close friend override tesla board majority shareholder another clear example biden administration ally weaponizing american legal system political opponent
# INDEX: 18, TEXT: getting tired talking probably important feel like elonmusk proving judge point reaction decision instead addressing governance concern highlighted decision misleadingly frame whole thing taking away shareholder right decide fact decision forcing new shareholder vote updated comp package crafted following rule public company presented shareholder transparent way would want know frustrating elon performance compensation delivered performance see way made whole need try see side elon instead misleading shareholder nature whole situation moving company incorporation texas kind point decision
# INDEX: 23, TEXT: viele reiche wie wenn man ein betreibt da bleibt auch fr da personal mehr geld hngen 1 sule der altersversorgung da zahlt jeder ein auch der schweizer elon musk marktabschottung rel hohe rumliche einwohnerdichte quasi alles stadt
# INDEX: 72, TEXT: sonko rejected request message wo delete mazee kot hii ni nyota ya jaha mazee ebu mnifikishe 5k nipate ii kazi ya sonko msikue kama watu wa rwanda na elon musk wako na wivu ata mimi nicheze na paypal mnipee 1 sausand retweets nifike
# INDEX: 122, TEXT: new york time january 23 2018 tesla elon musk may boldest pay plan corporate history musk somehow increase value tesla 650 billion figure many expert would contend laughably impossible would make tesla one five largest company united state based current valuation stock award could worth much 55 billion assuming company issue share next decade unrealistic even reaching several milestone would bring billion musk critic many likely contend new compensation plan company latest publicity stunt called barnum created illusion success consistently missing production estimate company continues lose money one point last year losing almost dollar hour according bloomberg news jim chanos bet tesla share thus far losing side trade contended tesla worthless
ia depresso alzheimer parkinson entre outras entretanto implicaes ticas sociais e de segurana levantam preocupaes sobre o riscos e benefcios de alterar funcionamento crebro humano alm disso neuralink enfrenta concorrncia de empresas com mais experincia na neurocincia que j implantaram dispositivos semelhantes projeto ainda est em fase de testis demandando estudos adicionais para comprovar sua eficcia e segurana impacto chip na sociedade e na humanidade permanece incerto sendo uma aposta arrojada de elon musk para transformar crebro humano em uma mquina artificial aqui est que implante neuralink foi projetado para permitir
# INDEX: 6447, TEXT: fck przeyam zabranianie czytania niewygodnych ksiek w epoce w polsce jedn z nich orwell rok 1984 oczywicie bdc w wieku 17 lat przeczytaam zarwno orwella jak tolkiena z 10 razy straszne czasy nastay obudcie si ludzie
# INDEX: 6479, TEXT: title critiquing biden border policy balancing compassion security navigating immigration policy biden administration face criticism perceived impact border security critic argue executive order halting border wall construction revising deportation priority prioritizing humane asylum process send mixed signal potentially encouraging illegal immigration handling southern border crisis also scrutinized concern overcrowded facility lack urgency administration aim compassionate approach debate center finding balance ensures security humanitarian consideration
# INDEX: 6557, TEXT: elon musk owner x still introduces elon musk elonmusk people nigerian igbo man precisely would changed name chief engineer architect programmer musk chukwuebuka elon bsc hod mac phd ksm nta gcfr hiv nba pta eze gburugburu 1 x eti okwe erie okwe spacex eze ngwori 1 malaysia odogwu tesla 1 na london ome na dollar na europe olimiri ego nekwu 1 nwa anayoeze osi ka ocheeche igbo kwenu thedarksam edited spoiltkid
# INDEX: 6560, TEXT: suka sama mama dedeh yang bilang jadi perempuan harus punya pendirian bener itu kenapa kita harus punya batasan kapan harus memaklumi dan kapan harus mengakhiri mau seganteng chris evans dan sekaya elon musk kalo gabisa menghargai wanitanya buat apa

# %%
df['token_lens'] = token_lens
# Out:
# <ipython-input-87-b06175d1d9b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['token_lens'] = token_lens

# %%
df = df.sort_values(by='token_lens', ascending=False)
df.head(20)
# Out:
#                                      preprocessed_tweet  sentiment  text_len  \
# 420   delaware ruling elon musk 55b comp package big...          2       550
# 8549  want know happening elon musk company today go...          2       890
# 9555  musk anuncia primeiro implante chip neuralink ...          1       301
# 6542  probably doubt need evidence system john adam ...          2       494
# 5358  matteo gracis qualche giorno fa attraverso x o...          2       315
# 2735  regulamentao da big tech j est acontecendo com...          2       218
# 4434  ellon musk act move tesla legal base texas jud...          2       291
# 6310  horizon scan ep 32 musk renumeration v decel c...          1       265
# 1236  point think pro 1 tax benefit texas offer favo...          2       285
# 8746  palestine never existed independent state army...          2       279
# 6067  elon musk anunciou oficialmente que sua empres...          1       143
# 1515  elonmusk judge kathaleen mccormick rescinded e...          2       186
# 5517  judge kathaleen mccormick rescinded elon musk ...          2       188
# 16    judge kathaleen mccormick rescinded elon musk ...          2       184
# 3157  delaware chancery court chief judge kathaleen ...          2       192
# 8374  terzaketv gaat het bij het hersenimplantaat va...          0        98
# 8270  circle 1 1 sovmichael 2 conceptualjames 3 jaco...          0        92
# 2511  ruling elon musk 56 billion comp package legal...          2       155
# 4997  good morning everybody egg x love free speech ...          2        63
# 735   tan slo unos da despus de que le colocaran uno...          1       107
#
#       token_lens
# 420          512
# 8549         512
# 9555         512
# 6542         512
# 5358         512
# 2735         441
# 4434         353
# 6310         335
# 1236         300
# 8746         296
# 6067         294
# 1515         235
# 5517         235
# 16           225
# 3157         224
# 8374         214
# 8270         211
# 2511         207
# 4997         195
# 735          194

# %%
df = df.iloc[12:]
df.head()
# Out:
#                                      preprocessed_tweet  sentiment  text_len  \
# 5517  judge kathaleen mccormick rescinded elon musk ...          2       188
# 16    judge kathaleen mccormick rescinded elon musk ...          2       184
# 3157  delaware chancery court chief judge kathaleen ...          2       192
# 8374  terzaketv gaat het bij het hersenimplantaat va...          0        98
# 8270  circle 1 1 sovmichael 2 conceptualjames 3 jaco...          0        92
#
#       token_lens
# 5517         235
# 16           225
# 3157         224
# 8374         214
# 8270         211

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#                                      preprocessed_tweet  sentiment  text_len  \
# 0      hayrdr olum uzayn tapusunu mu aldn amck elonmusk          0         8
# 1                     tell black making everything race          1         5
# 2     making theory basis meme depression real dude ...          2         9
# 3     america big trouble understand people see wake...          1        10
# 4     national embarrassment sad as pathetic life ps...          1        12
# ...                                                 ...        ...       ...
# 7196                     plastic surgeon destroyed face          0         4
# 7197  republican congress collaborating dems sneak b...          1        43
# 7198                 way become 3rd world country karma          0         6
# 7199                    slqq slaqq elonmusk presale gem          0         5
# 7200  elon musk neuralink implant computer chip brai...          0        19
#
#       token_lens
# 0             24
# 1              7
# 2             12
# 3             12
# 4             16
# ...          ...
# 7196           6
# 7197          51
# 7198           8
# 7199          16
# 7200          79
#
# [7201 rows x 4 columns]

# %%
df_test= df.sample(frac=1).reset_index(drop=True)

# %%
df_test
# Out:
#                                      preprocessed_tweet  sentiment  text_len  \
# 0                         brace year getting wilder day          0         5
# 1     see elonmusk climategate decline explained ber...          0        10
# 2     yet people still believe elonmusk make starshi...          0         8
# 3              shrug nothing like booger smeared finger          0         6
# 4     bernard arnault overtakes elon musk richest pe...          2        11
# ...                                                 ...        ...       ...
# 7196  1990 mulayam singh yadav ordered police firing...          0        32
# 7197  elon musk neuralink brain chip tested human sc...          0        12
# 7198  come back like old post well new one wonder be...          1        10
# 7199                   obviously watch video understand          0         4
# 7200                swamp getting back elon predictable          1         5
#
#       token_lens
# 0              7
# 1             16
# 2             14
# 3              9
# 4             21
# ...          ...
# 7196          55
# 7197          19
# 7198          12
# 7199           6
# 7200           8
#
# [7201 rows x 4 columns]

# %%
df['sentiment'].value_counts()
# Out:
# 2    2801
# 0    2735
# 1    1665
# Name: sentiment, dtype: int64

# %%
X = df_test['preprocessed_tweet'].values
y = df_test['sentiment'].values

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)

# %%
from imblearn.over_sampling import RandomOverSampler

# Now you can use RandomOverSampler
ros = RandomOverSampler()
train_x, train_y = ros.fit_resample(np.array(df['preprocessed_tweet']).reshape(-1, 1), np.array(df['sentiment']).reshape(-1, 1))
df_test = pd.DataFrame(list(zip([x[0] for x in train_x], train_y)), columns=['preprocessed_tweet', 'sentiment'])

# %%
from sklearn.model_selection import train_test_split

# Define a seed for reproducibility
seed = 42

# Now, use this seed in train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.1, stratify=y, random_state=seed)

# %%
X_test = df['preprocessed_tweet'].values
y_test = df['sentiment'].values

# %%
y_test
# Out:
# array([0, 1, 2, ..., 0, 0, 0])

# %%
y_train_le = y_train.copy()
y_valid_le = y_valid.copy()
y_test_le = y_test.copy()

# %%
from sklearn import preprocessing

# Now you can use preprocessing.OneHotEncoder
ohe = preprocessing.OneHotEncoder()
y_train = ohe.fit_transform(np.array(y_train).reshape(-1, 1)).toarray()
y_valid = ohe.fit_transform(np.array(y_valid).reshape(-1, 1)).toarray()
# Assuming y_test is defined
y_test = ohe.fit_transform(np.array(y_test).reshape(-1, 1)).toarray()

# %%
print(f"TRAINING DATA: {X_train.shape[0]}\nVALIDATION DATA: {X_valid.shape[0]}\nTESTING DATA: {X_test.shape[0]}" )
# Out:
# TRAINING DATA: 6480
# VALIDATION DATA: 721
# TESTING DATA: 7201

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Now you can use CountVectorizer
clf = CountVectorizer()
X_train_cv = clf.fit_transform(X_train)
X_test_cv = clf.transform(X_test)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# Now you can use TfidfTransformer
tf_transformer = TfidfTransformer(use_idf=True).fit(X_train_cv)
X_train_tf = tf_transformer.transform(X_train_cv)
X_test_tf = tf_transformer.transform(X_test_cv)

# %%
from sklearn.naive_bayes import MultinomialNB

# Now you can instantiate and use MultinomialNB
nb_clf = MultinomialNB()

# %%
nb_clf.fit(X_train_tf, y_train_le)
# Out:
# MultinomialNB()

# %%
nb_pred = nb_clf.predict(X_test_tf)

# %%
from sklearn.metrics import classification_report

# Assuming nb_pred and y_test_le are already defined with your predictions and test labels respectively
print('\tClassification Report for Naive Bayes:\n\n', classification_report(y_test_le, nb_pred, target_names=['Negative', 'Neutral', 'Positive']))
# Out:
# 	Classification Report for Naive Bayes:
#
#                precision    recall  f1-score   support
#
#     Negative       0.95      0.71      0.81      2735
#      Neutral       0.98      0.35      0.52      1665
#     Positive       0.60      0.98      0.75      2801
#
#     accuracy                           0.73      7201
#    macro avg       0.84      0.68      0.69      7201
# weighted avg       0.82      0.73      0.72      7201

# %%
MAX_LEN=128
def tokenize(data,max_len=MAX_LEN) :
    input_ids = []
    attention_masks = []
    for i in range(len(data)):
        encoded = tokenizer.encode_plus(
            data[i],
            add_special_tokens=True,
            max_length=MAX_LEN,
            padding='max_length',
            return_attention_mask=True
        )
        input_ids.append(encoded['input_ids'])
        attention_masks.append(encoded['attention_mask'])
    return np.array(input_ids),np.array(attention_masks)

# %%
import torch

def tokenize(data, max_len):
    input_ids = []
    attention_masks = []

    for sent in data:
        encoded = tokenizer.encode_plus(sent, add_special_tokens=True, max_length=max_len,
                                        pad_to_max_length=True, return_attention_mask=True, return_tensors='pt')
        input_ids.append(encoded['input_ids'])
        attention_masks.append(encoded['attention_mask'])

    # Convert lists to tensors
    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)

    return input_ids, attention_masks

# %%
train_input_ids, train_attention_masks = tokenize(X_train, MAX_LEN)
val_input_ids, val_attention_masks = tokenize(X_valid, MAX_LEN)
test_input_ids, test_attention_masks = tokenize(X_test, MAX_LEN)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2614: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
from transformers import TFBertModel

# Now you can use TFBertModel to load a pretrained BERT model
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
import tensorflow as tf

opt = tf.keras.optimizers.Adam(learning_rate=1e-5)

# %%
def create_model(bert_model, max_len=512):
    # Optimizer
    opt = tf.keras.optimizers.Adam(learning_rate=1e-5)
    loss = tf.keras.losses.CategoricalCrossentropy()
    accuracy = tf.keras.metrics.CategoricalAccuracy()

    # Model architecture
    input_ids = tf.keras.Input(shape=(max_len,), dtype='int32')
    attention_masks = tf.keras.Input(shape=(max_len,), dtype='int32')
    embeddings = bert_model([input_ids, attention_masks])[1]
    output = tf.keras.layers.Dense(3, activation="softmax")(embeddings)
    model = tf.keras.models.Model(inputs=[input_ids, attention_masks], outputs=output)

    # Compile the model
    model.compile(optimizer=opt, loss=loss, metrics=[accuracy])

    return model

# %%
from transformers import TFBertModel

# Load the BERT model
bert_model = TFBertModel.from_pretrained('bert-base-uncased')

# Create the model
model = create_model(bert_model, MAX_LEN)

# Check the model summary
model.summary()
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 128)]                0         []
#
#  input_4 (InputLayer)        [(None, 128)]                0         []
#
#  tf_bert_model_3 (TFBertMod  TFBaseModelOutputWithPooli   1094822   ['input_3[0][0]',
#  el)                         ngAndCrossAttentions(last_   40         'input_4[0][0]']
#                              hidden_state=(None, 128, 7
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  dense_1 (Dense)             (None, 3)                    2307      ['tf_bert_model_3[0][1]']
#
# ==================================================================================================
# Total params: 109484547 (417.65 MB)
# Trainable params: 109484547 (417.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
print(train_input_ids.shape)
print(train_attention_masks.shape)
print(y_train.shape)

print(val_input_ids.shape)
print(val_attention_masks.shape)
print(y_valid.shape)
# Out:
# torch.Size([6480, 128])
# torch.Size([6480, 128])
# (6480, 3)
# torch.Size([721, 128])
# torch.Size([721, 128])
# (721, 3)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': train_input_ids, 'attention_masks': train_attention_masks}, y_train))
train_dataset = train_dataset.shuffle(len(train_input_ids)).batch(32)

val_dataset = tf.data.Dataset.from_tensor_slices(({'input_ids': val_input_ids, 'attention_masks': val_attention_masks}, y_valid))
val_dataset = val_dataset.batch(32)

# %%
train_input_ids_np = train_input_ids.cpu().numpy()
train_attention_masks_np = train_attention_masks.cpu().numpy()
val_input_ids_np = val_input_ids.cpu().numpy()
val_attention_masks_np = val_attention_masks.cpu().numpy()

# %%
bert = model.fit(
    [train_input_ids_np, train_attention_masks_np],
    y_train,
    validation_data=([val_input_ids_np, val_attention_masks_np], y_valid),
    epochs=30,
    batch_size=64
)
# Out:
# Epoch 1/30
# 102/102 [==============================] - 183s 2s/step - loss: 0.9525 - categorical_accuracy: 0.5375 - val_loss: 0.8610 - val_categorical_accuracy: 0.6117
# Epoch 2/30
# 102/102 [==============================] - 159s 2s/step - loss: 0.7462 - categorical_accuracy: 0.6795 - val_loss: 0.7404 - val_categorical_accuracy: 0.7032
# Epoch 3/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.5840 - categorical_accuracy: 0.7670 - val_loss: 0.6676 - val_categorical_accuracy: 0.7462
# Epoch 4/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.4669 - categorical_accuracy: 0.8231 - val_loss: 0.6339 - val_categorical_accuracy: 0.7642
# Epoch 5/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.3695 - categorical_accuracy: 0.8702 - val_loss: 0.6701 - val_categorical_accuracy: 0.7573
# Epoch 6/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.2759 - categorical_accuracy: 0.9077 - val_loss: 0.7340 - val_categorical_accuracy: 0.7656
# Epoch 7/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.2086 - categorical_accuracy: 0.9346 - val_loss: 0.7758 - val_categorical_accuracy: 0.7656
# Epoch 8/30
# 102/102 [==============================] - 159s 2s/step - loss: 0.1590 - categorical_accuracy: 0.9522 - val_loss: 0.8759 - val_categorical_accuracy: 0.7670
# Epoch 9/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.1141 - categorical_accuracy: 0.9677 - val_loss: 0.9144 - val_categorical_accuracy: 0.7614
# Epoch 10/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0813 - categorical_accuracy: 0.9772 - val_loss: 0.9665 - val_categorical_accuracy: 0.7698
# Epoch 11/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0648 - categorical_accuracy: 0.9796 - val_loss: 0.9976 - val_categorical_accuracy: 0.7725
# Epoch 12/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0657 - categorical_accuracy: 0.9810 - val_loss: 1.0421 - val_categorical_accuracy: 0.7642
# Epoch 13/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0475 - categorical_accuracy: 0.9844 - val_loss: 1.1337 - val_categorical_accuracy: 0.7587
# Epoch 14/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0359 - categorical_accuracy: 0.9890 - val_loss: 1.1658 - val_categorical_accuracy: 0.7684
# Epoch 15/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0316 - categorical_accuracy: 0.9920 - val_loss: 1.2409 - val_categorical_accuracy: 0.7601
# Epoch 16/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0242 - categorical_accuracy: 0.9917 - val_loss: 1.2303 - val_categorical_accuracy: 0.7712
# Epoch 17/30
# 102/102 [==============================] - 159s 2s/step - loss: 0.0218 - categorical_accuracy: 0.9938 - val_loss: 1.2365 - val_categorical_accuracy: 0.7809
# Epoch 18/30
# 102/102 [==============================] - 159s 2s/step - loss: 0.0223 - categorical_accuracy: 0.9938 - val_loss: 1.2322 - val_categorical_accuracy: 0.7684
# Epoch 19/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0158 - categorical_accuracy: 0.9952 - val_loss: 1.4138 - val_categorical_accuracy: 0.7503
# Epoch 20/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0181 - categorical_accuracy: 0.9940 - val_loss: 1.3822 - val_categorical_accuracy: 0.7670
# Epoch 21/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0134 - categorical_accuracy: 0.9958 - val_loss: 1.3242 - val_categorical_accuracy: 0.7781
# Epoch 22/30
# 102/102 [==============================] - 164s 2s/step - loss: 0.0124 - categorical_accuracy: 0.9969 - val_loss: 1.3456 - val_categorical_accuracy: 0.7642
# Epoch 23/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0104 - categorical_accuracy: 0.9977 - val_loss: 1.3547 - val_categorical_accuracy: 0.7836
# Epoch 24/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0082 - categorical_accuracy: 0.9969 - val_loss: 1.4145 - val_categorical_accuracy: 0.7836
# Epoch 25/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0074 - categorical_accuracy: 0.9981 - val_loss: 1.3968 - val_categorical_accuracy: 0.7920
# Epoch 26/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0119 - categorical_accuracy: 0.9958 - val_loss: 1.4718 - val_categorical_accuracy: 0.7878
# Epoch 27/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0178 - categorical_accuracy: 0.9938 - val_loss: 1.3641 - val_categorical_accuracy: 0.7864
# Epoch 28/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0129 - categorical_accuracy: 0.9960 - val_loss: 1.2589 - val_categorical_accuracy: 0.7906
# Epoch 29/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0127 - categorical_accuracy: 0.9951 - val_loss: 1.3730 - val_categorical_accuracy: 0.7836
# Epoch 30/30
# 102/102 [==============================] - 163s 2s/step - loss: 0.0109 - categorical_accuracy: 0.9963 - val_loss: 1.4255 - val_categorical_accuracy: 0.7781

# %%
import tensorflow as tf

train_input_ids_tf = tf.convert_to_tensor(train_input_ids.cpu().numpy())
train_attention_masks_tf = tf.convert_to_tensor(train_attention_masks.cpu().numpy())
val_input_ids_tf = tf.convert_to_tensor(val_input_ids.cpu().numpy())
val_attention_masks_tf = tf.convert_to_tensor(val_attention_masks.cpu().numpy())

# %%
import tensorflow as tf

test_input_ids_tf = tf.convert_to_tensor(test_input_ids.cpu().numpy())
test_attention_masks_tf = tf.convert_to_tensor(test_attention_masks.cpu().numpy())

# Making predictions
result_bert = model.predict([test_input_ids_tf, test_attention_masks_tf])
# Out:
# 226/226 [==============================] - 66s 281ms/step

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Assuming your model outputs logits or softmax probabilities, and you need to convert these to class labels
y_pred_bert = result_bert.argmax(axis=1)

# %%
# Example of calculating the confusion matrix
y_true = y_test.argmax(axis=1)  # Adjust this line if necessary to match your data's structure


# Calculate the confusion matrix
cm = confusion_matrix(y_true, y_pred_bert)

# %%
# Plotting using seaborn
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Neutral', 'Positive'], yticklabels=['Negative', 'Neutral', 'Positive'])
plt.title('BERT Sentiment Analysis\nConfusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
if len(y_test.shape) > 1 and y_test.shape[1] > 1:  # Checks if y_test is one-hot encoded
    y_test = y_test.argmax(axis=1)

# %%
print('\tClassification Report for RoBERTa:\n\n', classification_report(y_test, y_pred_bert, target_names=['Negative', 'Neutral', 'Positive']))
# Out:
# 	Classification Report for RoBERTa:
#
#                precision    recall  f1-score   support
#
#     Negative       0.97      0.99      0.98      2735
#      Neutral       0.97      0.96      0.97      1665
#     Positive       0.99      0.97      0.98      2801
#
#     accuracy                           0.98      7201
#    macro avg       0.98      0.98      0.98      7201
# weighted avg       0.98      0.98      0.98      7201
